# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Web Scraping Lab**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# ## Objectives

# %% [markdown]
# After completing this lab, you will be able to:

# %% [markdown]
# * Download a webpage using requests module
# * Scrape all links from a webpage
# * Scrape all image URLs from a web page
# * Scrape data from html tables

# %% [markdown]
# ## Scrape www.ibm.com

# %% [markdown]
# Import the required modules and functions

# %%
from bs4 import BeautifulSoup 
import requests  
from bs4 import BeautifulSoup 
import requests

# %% [markdown]
# Download the contents of the webpage

# %%
url = "http://www.ibm.com"
url = "http://www.ibm.com"

# %%
data  = requests.get(url).text 
data  = requests.get(url).text

# %% [markdown]
# Create a soup object using the class BeautifulSoup

# %%
soup = BeautifulSoup(data,"html.parser")  
soup = BeautifulSoup(data, "html.parser")

# %% [markdown]
# Scrape all links

# %%
import requests
from bs4 import BeautifulSoup

url = "https://www.ibm.com/"

response = requests.get(url)

soup = BeautifulSoup(response.text, "html.parser")

for link in soup.find_all('a'):
    print(link.get('href'))
# Out:
# https://www.ibm.com/think/insights/accountability-gap-autonomous-ai?lnk=hpls1us
# https://www.hashicorp.com/en/products/vault?lnk=hpls2us
# https://bob.ibm.com/trial?lnk=hprc1us
# https://www.ibm.com/thought-leadership/institute-business-value/report/ai-sovereignty?lnk=hprc2us
# https://www.ibm.com/think/news/q-day-has-already-begun-are-you-ready?lnk=hprc3us
# https://www.hashicorp.com/en/events/webinars/securing-agentic-ai-vault-verify?lnk=hprc4us
# https://www.ibm.com/new/announcements/clients-rank-ibm-among-top-enterprise-software-providers-in-2026-g2-best-software-awards?lnk=hpfp1us
# https://bob.ibm.com?lnk=hpfp2us
# https://www.ibm.com/products/watsonx-orchestrate?lnk=hpfp3us
# https://www.ibm.com/products/confluent?lnk=hpfp4us
# https://www.ibm.com/products/flashsystem?lnk=hpfp5us
# https://www.hashicorp.com/en/products/vault?lnk=hpfp6us
# https://www.ibm.com/products/maximo?lnk=hpfp7us
# https://www.ibm.com/products/planning-analytics?lnk=hpfp8us
# https://www.ibm.com/consulting?lnk=hpfp9us
# None
# https://www.ibm.com/products/offers-and-discounts?lnk=hpdo1us
# https://www.ibm.com/case-studies/blue-pearl-bob?lnk=hpcs1us
# https://www.ibm.com/case-studies/riverty?lnk=hpcs2us
# https://www.ibm.com/case-studies/citadelle?lnk=hpcs3us
# https://www.ibm.com/case-studies/ibm-client-zero?lnk=hpcs4us
# https://www.ibm.com/training?utm_source=hp&utm_campaign=ushp&utm_medium=organic&lnk=hptr3us
# https://skillsbuild.org/adult-learners?lnk=hptr2us/?utm_source=ibm.com&utm_campaign=ibmus&utm_medium=organic
# https://skillsbuild.org/college-students?lnk=hptr1us/?utm_source=ibm.com&utm_campaign=ibmus&utm_medium=organic
# https://www.ibm.com/new/announcements/ibm-products-win-trustradius-2026-top-rated-awards
# https://newsroom.ibm.com/2026-06-26-ibm,-red-hat,-and-deloitte-announce-project-lightwell-collaboration-to-help-strengthen-open-source-software-supply-chain-trust
# https://newsroom.ibm.com/2026-06-24-ibm,-red-hat-and-palo-alto-networks-expand-project-lightwell-to-help-organizations-respond-to-software-vulnerabilities
# https://newsroom.ibm.com/2026-06-22-ibm-and-openai-bring-frontier-ai-to-cyber-defense-helping-enterprises-keep-pace-with-machine-speed-threats
# https://newsroom.ibm.com/2026-06-25-ibm-debuts-worlds-first-sub-1-nanometer-chip-technology
# https://newsroom.ibm.com/2026-06-22-wimbledon-and-ibm-introduce-new-ai-powered-fan-experiences-and-modernized-digital-platforms-for-the-championships-2026
# https://newsroom.ibm.com/2026-06-19-protecting-and-innovating-critical-infrastructure-through-new-security-landscapes
# https://newsroom.ibm.com/2026-06-17-ibm-study-limited-control-and-rising-dependencies-leave-enterprises-exposed-in-the-age-of-ai

# %% [markdown]
# Scrape  all images

# %%
for link in soup.find_all('img'):
    print(link.get('src'))
for link in soup.find_all('img'):
    print(link.get('src'))
# Out:
# /adobe/dynamicmedia/deliver/dm-p-oid--obbxEfsIG4AR1RIjYghD_sREGoq1iSfulBnXzijzeV0LHmgJtRq_2lGJ_7kd9o8OARcIHMexBjNOMNv99JUxBZShZ2fpX1_hJ9y5vqze0djL4kZnqmvZ0blOUKsFHXwLxYhWle_McRSQyxDOWMNODTqkP6m6xA5JRqEZjdTxWNc/homepage-vault-r4u-bob-001-v2.png?preferwebp=true&quality=90
# /adobe/dynamicmedia/deliver/dm-p-oid--obbxEfsIG4AR1RIjYghD_sREGoq1iSfulBnXzijzeV0LHmgJtRq_2lGJ_7kd9o8OARcIHMexBjNOMNv99JUxBZShZ2fpX1_hJ9y5vqze0dgNN_Xv8zLMLyMw58LLUtl9gtWi10tMFLmFz3oxl3ocecuC8FkUPqOVFBRf071ZwMQ/1637-leadspace-thumbnail.png?preferwebp=true&quality=90
# /adobe/dynamicmedia/deliver/dm-p-oid--obbxEfsIG4AR1RIjYghD_sREGoq1iSfulBnXzijzeV0LHmgJtRq_2lGJ_7kd9o8OARcIHMexBjNOMNv99JUxBZShZ2fpX1_hJ9y5vqze0djL4kZnqmvZ0blOUKsFHXwLmQq77iJezaHjTqt8WcHuOIGB_WVIZFILjHf-GutcGhc/homepage-vault-ibv-r4u-003.png?preferwebp=true&quality=90
# /adobe/dynamicmedia/deliver/dm-p-oid--obbxEfsIG4AR1RIjYghD_sREGoq1iSfulBnXzijzeV0LHmgJtRq_2lGJ_7kd9o8OARcIHMexBjNOMNv99JUxBZShZ2fpX1_hJ9y5vqze0djL4kZnqmvZ0blOUKsFHXwL46DrIprpRz9wfYqudWkyyp5zFniNkSnx0dLsr8oyYaE/homepage-vault-agentai-r4u-004.png?preferwebp=true&quality=90
# https://assets.ibm.com/is/image/ibm/big-blue-30-shopping-promotion-banner?ts=1782809650402&dpr=off
# https://assets.ibm.com/is/image/ibm/blue-pearl-logo-2x1-v2-1?ts=1782809651011&dpr=off
# https://assets.ibm.com/is/image/ibm/riverty-logo-2x1?ts=1782809651191&dpr=off
# https://assets.ibm.com/is/image/ibm/citadelle-logo-2x1?ts=1782809651378&dpr=off
# https://assets.ibm.com/is/image/ibm/ibm-logo-2x1?ts=1782809651561&dpr=off
# https://assets.ibm.com/is/image/ibm/homepage-training-professional-4x3?ts=1782809652150&dpr=off
# https://assets.ibm.com/is/image/ibm/homepage-training-foundational-4x3?ts=1782809653067&dpr=off
# https://assets.ibm.com/is/image/ibm/homepage-training-students-4x3?ts=1782809653971&dpr=off
# https://assets.ibm.com/is/image/ibm/stay-connected-homepage-people-16x9?ts=1782809655779&dpr=off
# /adobe/dynamicmedia/deliver/dm-p-oid--obbxEfsIG4AR1RIjYghD_sREGoq1iSfulBnXzijzeV0LHmgJtRq_2lGJ_7kd9o8OARcIHMexBjNOMNv99JUxBZShZ2fpX1_hJ9y5vqze0djL4kZnqmvZ0blOUKsFHXwLxYhWle_McRSQyxDOWMNODTqkP6m6xA5JRqEZjdTxWNc/homepage-vault-r4u-bob-001-v2.png?preferwebp=true&quality=90
# /adobe/dynamicmedia/deliver/dm-p-oid--obbxEfsIG4AR1RIjYghD_sREGoq1iSfulBnXzijzeV0LHmgJtRq_2lGJ_7kd9o8OARcIHMexBjNOMNv99JUxBZShZ2fpX1_hJ9y5vqze0dgNN_Xv8zLMLyMw58LLUtl9gtWi10tMFLmFz3oxl3ocecuC8FkUPqOVFBRf071ZwMQ/1637-leadspace-thumbnail.png?preferwebp=true&quality=90
# /adobe/dynamicmedia/deliver/dm-p-oid--obbxEfsIG4AR1RIjYghD_sREGoq1iSfulBnXzijzeV0LHmgJtRq_2lGJ_7kd9o8OARcIHMexBjNOMNv99JUxBZShZ2fpX1_hJ9y5vqze0djL4kZnqmvZ0blOUKsFHXwLmQq77iJezaHjTqt8WcHuOIGB_WVIZFILjHf-GutcGhc/homepage-vault-ibv-r4u-003.png?preferwebp=true&quality=90
# /adobe/dynamicmedia/deliver/dm-p-oid--obbxEfsIG4AR1RIjYghD_sREGoq1iSfulBnXzijzeV0LHmgJtRq_2lGJ_7kd9o8OARcIHMexBjNOMNv99JUxBZShZ2fpX1_hJ9y5vqze0djL4kZnqmvZ0blOUKsFHXwL46DrIprpRz9wfYqudWkyyp5zFniNkSnx0dLsr8oyYaE/homepage-vault-agentai-r4u-004.png?preferwebp=true&quality=90
# https://assets.ibm.com/is/image/ibm/big-blue-30-shopping-promotion-banner?ts=1782809650402&dpr=off
# https://assets.ibm.com/is/image/ibm/blue-pearl-logo-2x1-v2-1?ts=1782809651011&dpr=off
# https://assets.ibm.com/is/image/ibm/riverty-logo-2x1?ts=1782809651191&dpr=off
# https://assets.ibm.com/is/image/ibm/citadelle-logo-2x1?ts=1782809651378&dpr=off
# https://assets.ibm.com/is/image/ibm/ibm-logo-2x1?ts=1782809651561&dpr=off
# https://assets.ibm.com/is/image/ibm/homepage-training-professional-4x3?ts=1782809652150&dpr=off
# https://assets.ibm.com/is/image/ibm/homepage-training-foundational-4x3?ts=1782809653067&dpr=off
# https://assets.ibm.com/is/image/ibm/homepage-training-students-4x3?ts=1782809653971&dpr=off
# https://assets.ibm.com/is/image/ibm/stay-connected-homepage-people-16x9?ts=1782809655779&dpr=off

# %% [markdown]
# ## Scrape data from html tables

# %%
URL = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/datasets/HTMLColorCodes.html"
URL = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/datasets/HTMLColorCodes.html"

# %% [markdown]
# Before proceeding to scrape a website, you need to examine the contents, and the way data is organized on the website. Open the above URL in your browser and check how many rows and columns are there in the color table.

# %%
data  = requests.get(URL).text
data =  requests.get(URL).text

# %%
soup = BeautifulSoup(data,"html.parser")
soup = BeautifulSoup(data, "html.parser")

# %%
table = soup.find('table') # in html table is represented by the tag <table>
table = soup.find('table')

# %% [markdown]
# # Get all rows from the table

# %%
for row in table.find_all('tr'): # in html table row is represented by the tag <tr>
    # Get all columns in each row.
    cols = row.find_all('td') # in html a column is represented by the tag <td>
    color_name = cols[2].getText() # store the value in column 3 as color_name
    color_code = cols[3].getText() # store the value in column 4 as color_code
    print("{}--->{}".format(color_name,color_code))

for row in table.find_all('tr'):
    cols = row.find_all('td')
    color_name = cols[2].getText()
    color_code = cols[2].getText() 
    print("{}--->{}".format(color_name,color_code))
# Out:
# Color Name--->Hex Code#RRGGBB
# lightsalmon--->#FFA07A
# salmon--->#FA8072
# darksalmon--->#E9967A
# lightcoral--->#F08080
# coral--->#FF7F50
# tomato--->#FF6347
# orangered--->#FF4500
# gold--->#FFD700
# orange--->#FFA500
# darkorange--->#FF8C00
# lightyellow--->#FFFFE0
# lemonchiffon--->#FFFACD
# papayawhip--->#FFEFD5
# moccasin--->#FFE4B5
# peachpuff--->#FFDAB9
# palegoldenrod--->#EEE8AA
# khaki--->#F0E68C
# darkkhaki--->#BDB76B
# yellow--->#FFFF00
# lawngreen--->#7CFC00
# chartreuse--->#7FFF00
# limegreen--->#32CD32
# lime--->#00FF00
# forestgreen--->#228B22
# green--->#008000
# powderblue--->#B0E0E6
# lightblue--->#ADD8E6
# lightskyblue--->#87CEFA
# skyblue--->#87CEEB
# deepskyblue--->#00BFFF
# lightsteelblue--->#B0C4DE
# dodgerblue--->#1E90FF
# Color Name--->Color Name
# lightsalmon--->lightsalmon
# salmon--->salmon
# darksalmon--->darksalmon
# lightcoral--->lightcoral
# coral--->coral
# tomato--->tomato
# orangered--->orangered
# gold--->gold
# orange--->orange
# darkorange--->darkorange
# lightyellow--->lightyellow
# lemonchiffon--->lemonchiffon
# papayawhip--->papayawhip
# moccasin--->moccasin
# peachpuff--->peachpuff
# palegoldenrod--->palegoldenrod
# khaki--->khaki
# darkkhaki--->darkkhaki
# yellow--->yellow
# lawngreen--->lawngreen
# chartreuse--->chartreuse
# limegreen--->limegreen
# lime--->lime
# forestgreen--->forestgreen
# green--->green
# powderblue--->powderblue
# lightblue--->lightblue
# lightskyblue--->lightskyblue
# skyblue--->skyblue
# deepskyblue--->deepskyblue
# lightsteelblue--->lightsteelblue
# dodgerblue--->dodgerblue

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# <!--
# ## Change Log
# |  Date (YYYY-MM-DD) |  Version | Changed By  |  Change Description |
# |---|---|---|---|
# | 2024-10-29  | 0.2  | Madhusudhan Moole |  Updated lab |
# | 2020-10-17  | 0.1  | Ramesh Sannareddy  |  Created initial version of the lab |
# --!>

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
